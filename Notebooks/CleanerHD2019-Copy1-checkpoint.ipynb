# %%
import pandas as pd

# %% [markdown]
# #Load table for data wrangling

# %%
HD2019A = pd.read_csv("../Data/HD2019A.csv")

# %% [markdown]
# #Take a look

# %%
HD2019A.head()
# Out:
#    UNITID                               INSTNM  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1                                                NaN
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4                                                NaN
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# ...

# %% [markdown]
# #Delete Irrelevant Columns

# %%
HD2019A.drop(['IALIAS'], axis=1, inplace=True)

# %%
HD2019A.drop(['ADDR'], axis=1, inplace=True)

# %%
HD2019A.drop(['CITY'], axis=1, inplace=True)

# %%
HD2019A.drop(['STABBR'], axis=1, inplace=True)

# %%
HD2019A.drop(['ZIP'], axis=1, inplace=True)

# %%
HD2019A.drop(['CHFNM'], axis=1, inplace=True)

# %%
HD2019A.drop(['GENTELE'], axis=1, inplace=True)

# %%
HD2019A.drop(['EIN'], axis=1, inplace=True)

# %%
HD2019A.drop(['DUNS'], axis=1, inplace=True)

# %%
HD2019A.drop(['OPEID'], axis=1, inplace=True)

# %%
HD2019A.drop(['OPEFLAG'], axis=1, inplace=True)

# %%
HD2019A.drop(['WEBADDR'], axis=1, inplace=True)

# %%
HD2019A.drop(['ADMINURL'], axis=1, inplace=True)

# %%
HD2019A.drop(['FAIDURL'], axis=1, inplace=True)

# %%
HD2019A.drop(['APPLURL'], axis=1, inplace=True)

# %%
HD2019A.drop(['NPRICURL'], axis=1, inplace=True)

# %%
HD2019A.drop(['VETURL'], axis=1, inplace=True)

# %%
HD2019A.drop(['ATHURL'], axis=1, inplace=True)

# %%
HD2019A.drop(['DISAURL'], axis=1, inplace=True)

# %%
HD2019A.drop(['CONTROL'], axis=1, inplace=True)

# %%
HD2019A.drop(['HOSPITAL'], axis=1, inplace=True)

# %%
HD2019A.drop(['MEDICAL'], axis=1, inplace=True)

# %%
HD2019A.drop(['CARNEGIE'], axis=1, inplace=True)

# %%
HD2019A.drop(['OPENPUBL'], axis=1, inplace=True)

# %%
HD2019A.drop(['ACT'], axis=1, inplace=True)

# %%
HD2019A.drop(['NEWID'], axis=1, inplace=True)

# %%
HD2019A.drop(['DEATHYR'], axis=1, inplace=True)

# %%
HD2019A.drop(['CLOSEDAT'], axis=1, inplace=True)

# %%
HD2019A.drop(['CYACTIVE'], axis=1, inplace=True)

# %%
HD2019A.drop(['POSTSEC'], axis=1, inplace=True)

# %%
HD2019A.drop(['PSEFLAG'], axis=1, inplace=True)

# %%
HD2019A.drop(['PSET4FLG'], axis=1, inplace=True)

# %%
HD2019A.drop(['RPTMTH'], axis=1, inplace=True)

# %%
HD2019A.drop(['C18IPUG'], axis=1, inplace=True)

# %%
HD2019A.drop(['C18IPGRD'], axis=1, inplace=True)

# %%
HD2019A.drop(['C18UGPRF'], axis=1, inplace=True)

# %%
HD2019A.drop(['C18SZSET'], axis=1, inplace=True)

# %%
HD2019A.drop(['C18ENPRF'], axis=1, inplace=True)

# %%
HD2019A.drop(['C15BASIC'], axis=1, inplace=True)

# %%
HD2019A.drop(['LANDGRNT'], axis=1, inplace=True)

# %%
HD2019A.drop(['F1SYSTYP'], axis=1, inplace=True)

# %%
HD2019A.drop(['F1SYSCOD'], axis=1, inplace=True)

# %%
HD2019A.drop(['F1SYSNAM'], axis=1, inplace=True)

# %%
HD2019A.drop(['CBSA'], axis=1, inplace=True)

# %%
HD2019A.drop(['CBSATYPE'], axis=1, inplace=True)

# %%
HD2019A.drop(['CSA'], axis=1, inplace=True)

# %%
HD2019A.drop(['NECTA'], axis=1, inplace=True)

# %%
HD2019A.drop(['COUNTYCD'], axis=1, inplace=True)

# %%
HD2019A.drop(['COUNTYNM'], axis=1, inplace=True)

# %%
HD2019A.drop(['CNGDSTCD'], axis=1, inplace=True)

# %%
HD2019A.drop(['LONGITUD'], axis=1, inplace=True)

# %%
HD2019A.drop(['LATITUDE'], axis=1, inplace=True)

# %%
HD2019A.drop(['DFRCGID'], axis=1, inplace=True)

# %%
HD2019A.drop(['DFRCUSCG'], axis=1, inplace=True)

# %% [markdown]
# #Take a look

# %%
HD2019A.head()
# Out:
#    UNITID                               INSTNM  FIPS  OBEREG   CHFTITLE  \
# 0  100654             Alabama A & M University     1       5  President
# 1  100663  University of Alabama at Birmingham     1       5  President
# 2  100690                   Amridge University     1       5  President
# 3  100706  University of Alabama in Huntsville     1       5  President
# 4  100724             Alabama State University     1       5  President
#
#    SECTOR  ICLEVEL  HLOFFER  UGOFFER  GROFFER  HDEGOFR1  DEGGRANT  HBCU  \
# 0       1        1        9        1        1        12         1     1
# 1       1        1        9        1        1        11         1     2
# 2       2        1        9        1        1        12         1     2
# 3       1        1        9        1        1        11         1     2
# 4       1        1        9        1        1        11         1     1
#
#    TRIBAL  LOCALE  INSTCAT  C18BASIC  CCBASIC  INSTSIZE
# ...

# %% [markdown]
# #Saw that I forgot to delete one column

# %%
HD2019A.drop(['CHFTITLE'], axis=1, inplace=True)

# %% [markdown]
# #Take a look

# %%
HD2019A.head()
# Out:
#    UNITID                               INSTNM  FIPS  OBEREG  SECTOR  ICLEVEL  \
# 0  100654             Alabama A & M University     1       5       1        1
# 1  100663  University of Alabama at Birmingham     1       5       1        1
# 2  100690                   Amridge University     1       5       2        1
# 3  100706  University of Alabama in Huntsville     1       5       1        1
# 4  100724             Alabama State University     1       5       1        1
#
#    HLOFFER  UGOFFER  GROFFER  HDEGOFR1  DEGGRANT  HBCU  TRIBAL  LOCALE  \
# 0        9        1        1        12         1     1       2      12
# 1        9        1        1        11         1     2       2      12
# 2        9        1        1        12         1     2       2      12
# 3        9        1        1        11         1     2       2      12
# 4        9        1        1        11         1     1       2      12
#
#    INSTCAT  C18BASIC  CCBASIC  INSTSIZE
# ...

# %% [markdown]
# #Rename Columns

# %%
 HD2019B = HD2019A.rename(columns={'INSTNM': 'InstitutionName', 'FIPS': 'State-Country', 'OBEREG': 'Region','ICLEVEL': 'Level','HLOFFER': 'HighestDegreeOffered'})

# %%
 HD2019C = HD2019B.rename(columns={'UGOFFER': 'UnderGradOfferings','GROFFER': 'GradOfferings', 'HDEGOFR1': 'DegreeOffered', 'DEGGRANT': 'DegreeGrantingYN', 'LOCALE': 'DegreeOfUrban'})

# %%
 HD2019D = HD2019C.rename(columns={'INSTCAT': 'InstCatOfProg', 'CCBASIC': 'MajorFields', 'C18BASIC': 'Degrees-Majors','INSTSIZE': 'InstSize'})

# %% [markdown]
# #Take a look

# %%
HD2019D.head()
# Out:
#    UNITID                      InstitutionName  State-Country  Region  SECTOR  \
# 0  100654             Alabama A & M University              1       5       1
# 1  100663  University of Alabama at Birmingham              1       5       1
# 2  100690                   Amridge University              1       5       2
# 3  100706  University of Alabama in Huntsville              1       5       1
# 4  100724             Alabama State University              1       5       1
#
#    Level  HighestDegreeOffered  UnderGradOfferings  GradOfferings  \
# 0      1                     9                   1              1
# 1      1                     9                   1              1
# 2      1                     9                   1              1
# 3      1                     9                   1              1
# 4      1                     9                   1              1
#
#    DegreeOffered  DegreeGrantingYN  HBCU  TRIBAL  DegreeOfUrban  \
# ...

# %% [markdown]
# #Delete Missing Values

# %%
HD2019D.dropna(inplace=True)

# %% [markdown]
# #Take a look

# %%
HD2019D.head()
# Out:
#    UNITID                      InstitutionName  State-Country  Region  SECTOR  \
# 0  100654             Alabama A & M University              1       5       1
# 1  100663  University of Alabama at Birmingham              1       5       1
# 2  100690                   Amridge University              1       5       2
# 3  100706  University of Alabama in Huntsville              1       5       1
# 4  100724             Alabama State University              1       5       1
#
#    Level  HighestDegreeOffered  UnderGradOfferings  GradOfferings  \
# 0      1                     9                   1              1
# 1      1                     9                   1              1
# 2      1                     9                   1              1
# 3      1                     9                   1              1
# 4      1                     9                   1              1
#
#    DegreeOffered  DegreeGrantingYN  HBCU  TRIBAL  DegreeOfUrban  \
# ...

# %% [markdown]
# #Look at Value Counts

# %%
HD2019D.value_counts()
# Out:
# UNITID  InstitutionName                                                         State-Country  Region  SECTOR  Level  HighestDegreeOffered  UnderGradOfferings  GradOfferings  DegreeOffered  DegreeGrantingYN  HBCU  TRIBAL  DegreeOfUrban  InstCatOfProg  Degrees-Majors  MajorFields  InstSize
# 100654  Alabama A & M University                                                1              5       1        1      9                     1                   1              12             1                1     2       12              2              18              18           3          1
# 413945  Toni & Guy Hairdressing Academy-Atlanta                                 13             5       9        3      2                     1                   2              0              2                2     2       13              6             -2              -2            1          1
# ...

# %% [markdown]
# #Take a look

# %%
HD2019D
# Out:
#       UNITID                                    InstitutionName  \
# 0     100654                           Alabama A & M University
# 1     100663                University of Alabama at Birmingham
# 2     100690                                 Amridge University
# 3     100706                University of Alabama in Huntsville
# 4     100724                           Alabama State University
# ...      ...                                                ...
# 6554  494889                              Baker College - Flint
# 6555  494898         WellSpring School of Allied Health-Wichita
# 6556  494904                            Access Careers-Islandia
# 6557  494913          Franciscan School of Theology - San Diego
# 6558  494922  University of Montana (The) - Bitterroot Colle...
#
#       State-Country  Region  SECTOR  Level  HighestDegreeOffered  \
# 0                 1       5       1      1                     9
# ...

# %% [markdown]
# #Export clean table to folder

# %%
HD2019D.to_csv(r'C:\Users\jenni\Desktop\DataScience\Final Project\HD2019DClean.csv', index=False)
