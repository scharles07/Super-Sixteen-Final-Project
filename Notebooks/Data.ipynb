# %%
import pandas as pd

# %%
data = pd.read_csv("../Data/IGR_Prediction_DS.csv")

# %%
data.head()
# Out:
#    chg1ay3  chg4ay3  chg5ay3  chg6ay3  chg7ay3  chg8ay3  chg9ay3   ENRLM  \
# 0   3640.0   1800.0   4770.0   2600.0   4770.0   2600.0   1300.0   551.0
# 1   4792.0    900.0  12266.0   2438.0  11868.0   3375.0   3375.0   612.0
# 2   4848.0    720.0   6820.0   2176.0   6820.0   2176.0   2176.0   449.0
# 3   4008.0   1000.0   3600.0   2310.0   5625.0   2310.0   2820.0   542.0
# 4   5278.0    950.0   8550.0   3093.0      NaN      NaN      NaN  1960.0
#
#     ENRLW   ENRLT  ...  F3EQUITR  PctEnrWh  PctEnrBK  PctEnrHS  PctEnrAP  \
# 0   586.0  1137.0  ...       NaN       5.0      89.0       1.0       0.0
# 1   919.0  1531.0  ...       NaN      62.0      25.0       1.0       4.0
# 2   389.0   838.0  ...       NaN      73.0      13.0       2.0       3.0
# 3   671.0  1213.0  ...       NaN       4.0      95.0       0.0       0.0
# 4  2418.0  4378.0  ...       NaN      81.0      11.0       2.0       1.0
#
#    PctEnrAN  PctEnrUn  PctEnrNr  DVEF06  GBA4RTT
# ...
