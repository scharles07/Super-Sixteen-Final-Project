# %%
import pandas as pd

# %%
#Subsetting Columns

# %%
C2019_B = pd.read_excel("C2019_B.xlsx")

# %%
display(C2019_B)
# Out:
#       UNITID  CSTOTLT  CSTOTLM  CSTOTLW  CSAIANT  CSAIANM  CSAIANW  CSASIAT  \
# 0     100654      810      298      512        4        1        3        4
# 1     100663     5449     2028     3421       15        7        8      301
# 2     100690      172       63      109        1        0        1        2
# 3     100706     1934      992      942       18       10        8       70
# 4     100724      663      227      436        0        0        0       10
# ...      ...      ...      ...      ...      ...      ...      ...      ...
# 6229  494746      264       67      197        3        1        2       70
# 6230  494834       33        9       24        0        0        0        0
# 6231  494843      317       24      293        1        0        1        3
# 6232  494852      283       82      201        4        1        3        4
# 6233  494904      204       19      185        0        0        0        7
#
# ...

# %%
C2019_B.shape
# Out:
# (6234, 31)

# %%
col_range = list(range(5))
col_range
# Out:
# [0, 1, 2, 3, 4]

# %%
C2019_B1 = df.iloc[:,col_range]
C2019_B1
# Out:
#       UNITID  CSTOTLT  CSTOTLM  CSTOTLW
# 0     100654      810      298      512
# 1     100663     5449     2028     3421
# 2     100690      172       63      109
# 3     100706     1934      992      942
# 4     100724      663      227      436
# ...      ...      ...      ...      ...
# 6229  494746      264       67      197
# 6230  494834       33        9       24
# 6231  494843      317       24      293
# 6232  494852      283       82      201
# 6233  494904      204       19      185
#
# [6234 rows x 4 columns]

# %%
col_range = list(range(0,4))
col_range
# Out:
# [0, 1, 2, 3]

# %%
C2019_B2 = df.iloc[:,col_range]
C2019_B2
# Out:
#       UNITID  CSTOTLT  CSTOTLM  CSTOTLW
# 0     100654      810      298      512
# 1     100663     5449     2028     3421
# 2     100690      172       63      109
# 3     100706     1934      992      942
# 4     100724      663      227      436
# ...      ...      ...      ...      ...
# 6229  494746      264       67      197
# 6230  494834       33        9       24
# 6231  494843      317       24      293
# 6232  494852      283       82      201
# 6233  494904      204       19      185
#
# [6234 rows x 4 columns]

# %%
#Rename Columns

# %%
C2019_B.columns
# Out:
# Index(['UNITID', 'Grand Total', 'Grand Total Men', 'Grand Total Women'], dtype='object')

# %%
C2019_B.rename(columns = {'CSTOTLT':'Grand Total','CSTOTLM':'Grand Total Men','CSTOTLW':'Grand Total Women'},inplace=True)
# Out:
# /var/folders/dw/8167w2j97bg6t7g3l3pdk3y80000gn/T/ipykernel_4291/3501986500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   C2019_B.rename(columns = {'CSTOTLT':'Grand Total','CSTOTLM':'Grand Total Men','CSTOTLW':'Grand Total Women'},inplace=True)

# %%
C2019_B.columns
# Out:
# Index(['UNITID', 'Grand Total', 'Grand Total Men', 'Grand Total Women'], dtype='object')

# %%
C2019_B.head()
# Out:
#    UNITID  Grand Total  Grand Total Men  Grand Total Women
# 0  100654          810              298                512
# 1  100663         5449             2028               3421
# 2  100690          172               63                109
# 3  100706         1934              992                942
# 4  100724          663              227                436
